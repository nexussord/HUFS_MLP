# %% [markdown]
# # 텍스트 마이닝을 활용한 영화 평점 감성 분석

# %% [markdown]
# ## 1) 영화 평점 데이터 크롤링

# %%
import requests
from bs4 import BeautifulSoup
from urllib import parse

base_url = "https://movie.naver.com/movie/point/af/list.naver?st=mcode&sword=208077&target=after&page={}"
url = base_url.format(1)
res = requests.get(url)

soup = BeautifulSoup(res.text)
tds = soup.select('table.list_netizen > tbody > tr > td.title')

for td in tds:
    movie_title = td.select_one('a.movie').text.strip()
    score = td.select_one('div.list_netizen_score > em').text.strip()
    comment = td.select_one('br').next_sibling.strip()
    print(movie_title, score, comment, sep=' :: ')
    print('-------------------------------------------')
# Out:
# 스파이더맨: 노 웨이 홈 :: 10 ::
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 10 :: 너무나도 잼있게 보았습니다!!!!
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 8 :: 올해 가장 만족스러운 마블 영화인 동시에 선물같은 영화
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 10 :: 역시 스파이더맨
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 4 :: 기대이하이고 , 넘 실망스러운게 억지감동이 심함 일류배우들이 나오는 삼류스토리;;
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 10 :: 다 좋았는데 톰홀랜드가 초반에 발암유발자였다
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 10 :: 남자는 태어나서 3번운다. 스파이더맨 노웨이홈을 보면서 3번운다.
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 10 :: 레전드다이거는너무재밌게 봤다
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 8 :: -2점은 스파이더맨을 보지 않은 사람들에 대한 경고. 한번도 다른 스파이더맨 영화를 보지 않고 이 영화를 보려는 사람은 그 시도를 멈추라!! 정말 재미없을 것이다.
# -------------------------------------------
# 스파이더맨: 노 웨이 홈 :: 10 :: 원래 자리로 돌아온 다정한 이웃 스파이더맨. 이렇게 잘 싸매서 돌려준다니 마블 너어..
# -------------------------------------------

# %%
import time
import random

comment_list=[] # 저장 할 리스트
for page in range(1, 1001):
    url = base_url.format(page)
    res = requests.get(url)
    
    soup = BeautifulSoup(res.text, 'lxml')
    tds = soup.select('table.list_netizen > tbody > tr > td.title')
    
    for td in tds:
        score = td.select_one('div.list_netizen_score > em').text.strip()
        comment = td.select_one('br').next_sibling.strip()
        if comment != '' : # comment가 빈값이 아니라면 리스트에 추가
            comment_list.append((score, comment)) 
    delay = round(random.uniform(0.2, 1.2), 2) # 크롤링을 위해 페이지 전환을 빠르게 하게되면 네이버에서 막을 수 있기에 delay를 걸어준다.
    time.sleep(delay)

# %%
print(comment_list)
# Out:
# [('10', '스파이더맨 최고~~'), ('10', '123,12 다 보고가길, 레전드에요'), ('9', '영화 끝나기도 전에 또 보고 싶어졌다'), ('1', '마블은 이제 끝난듯...'), ('10', '너무나도 잼있게 보았습니다!!!!'), ('8', '올해 가장 만족스러운 마블 영화인 동시에 선물같은 영화'), ('10', '역시 스파이더맨'), ('4', '기대이하이고 , 넘 실망스러운게 억지감동이 심함 일류배우들이 나오는 삼류스토리;;'), ('10', '다 좋았는데 톰홀랜드가 초반에 발암유발자였다'), ('10', '남자는 태어나서 3번운다. 스파이더맨 노웨이홈을 보면서 3번운다.'), ('10', '레전드다이거는너무재밌게 봤다'), ('8', '-2점은 스파이더맨을 보지 않은 사람들에 대한 경고. 한번도 다른 스파이더맨 영화를 보지 않고 이 영화를 보려는 사람은 그 시도를 멈추라!! 정말 재미없을 것이다.'), ('10', '원래 자리로 돌아온 다정한 이웃 스파이더맨. 이렇게 잘 싸매서 돌려준다니 마블 너어..'), ('10', '넌 어메이징 해~'), ('10', '눈물이 차올라서 고갤들어.. 흐르지 못하게 또 살짝 웃어내게 왜 이러는지 무슨 말을 하는지~..'), ('9', '치유와 새로운 시작 스파이디 사랑해'), ('10', '며칠전 스파이더맨을 봤다. 참 재밌었다.!'), ('10', '엔드게임의 여운을 엔드 해버릴만한 감동'), ('9', '아이언맨 후광을 완전 벗어난 스파이더맨을 3편에 이르러서야 봤다. 토비맥과이어의 4편을 간절히 바랬던 1인으로서 그 소망이 이루어지지 않아 아쉬웠는데, 이번 톰스파는 4편까지 훨훨 날아줬으면 좋겠다. 아연맨이 빠진 시리즈는 더 이상 의미없을거라 생각했는데, 그 다음 의미를 새롭게 가지게 해준 기특한 스파이더맨. 사랑스럽다. 4편 열렬히 기대함.'), ('8', '평점 9점이상 받을만한 영화는 아니지만 엔드게임 이후로 폭망한 마블영화중 선방했다. 닥터스트레인지2와 토르4 기대해보자'), ('10', '걍최고 말잇못 더이상할말이없음'), ('1', '개연성도 없고 공감도 안되고'), ('10', '너무재밌게봤어요~시간가는줄모르고 몰입해서 봤습니당'), ('10', '단언컨대 절대로 스포 당하면 안되는 영화!'), ('6', '피터 파커들의 동문회만큼은 강렬하다'), ('10', '삼파이더맨의 출현이 너무 소름 돋았음. 스파이디팬 이라면 꼭 봐야 하는 영화. 마블이 준 크리스마스 선물'), ('10', '잊고있던 내 안의 스파이디를 꺼내서 들이밀어줬고 아 맞다 나 스파이더맨 좋아했었네 라고 생각하게 해줌'), ('10', '이건 역대급이다. 꼭 봐야함'), ('1', '심형래가 만든영화가 700배는 안유치하고 재밌을듯'), ('10', '토비 맥과이어를 다시 볼 수 있어서 너무 좋았다. 정말 행복했다.'), ('10', '스파이더맨을 사랑했던 마블과 팬들을 위한 대서사시'), ('10', '눈물만 박박 흘리다옴....'), ('10', '재밌음....또 보러갈거'), ('9', '개연성은 조금 부족했지만 ㄹㅇ 최고의 스파이더맨연출 액션 스토리 ost 다 최고였음 꼭 보시길ㄹㅇ 웅장이 가슴해졌다 엔겜다음 최고의 마블 영화'), ('10', '마블영화는 언제나 최고'), ('10', '최고'), ('1', '스파이더맨 무능력하고 사고만 쳐서 완전 암덩어리네요~ 그 무능력한 스파이더맨이 3명이나 쳐나와서  보다가 답답해서 뛰쳐나갈뻔 했네요.영화 중간중간에 신파극이나 농담은 하나도 재미 없구요... 이게 왜 평점이 좋은지.. 내가 이상한건가 싶네요.... 저한텐 완전 OOO기 역대 최악이였음!'), ('8', '소니 스파이더맨이나 코믹스 원작 팬들에게는 명작이겠지만, mcu 팬 입장에선 애매하게 느껴졌음. 감동과 추억을 위해 개연성을 희생했는데, 스파이더맨에 추억이 없는 사람들은 희생된 개연성에 의문만 남을 듯'), ('10', '1대 스파이더맨부터 차곡차곡 쌓아온 기대했던 만큼 넘나 만족했습니다ㅎㅎ'), ('4', '액션신빼고는 지루했다.'), ('10', '천만 가즈아 레전드급 출연진'), ('10', '진짜 역대급;;;; 또볼거임'), ('10', '내인생에 첫 10점이다. 이건 10점 줘야한다.'), ('10', '액션은 살짝 모자라지만 다른건 대 만족'), ('10', '최고의 영화입니다. 기대하고 보셔도 됩니다.'), ('10', '코로나만 아니면 천만영화'), ('10', '영원불멸'), ('10', '그냥 최고살짝 울컥했음 물론 원래 눈물이 많음'), ('10', '마블이 올해 마지막을 위해 관객에게 선사하는 추억선물'), ('10', '삼스파 한 작품 출연 추진한 사람 진짜 상 줘야 한다고 생각함..마블민국 마블국민으로 살면서 이렇게 선물처럼 느껴지는 감동은 또 처음ㅠㅠ역시 최고다! 사랑해 마블? 사랑해 삼스파'), ('8', '현혹할만 했던 예고편..'), ('10', '굳'), ('10', '재밌고, 슬프고, 감동적이네요'), ('8', '평점 9점대길래 기대했는데 그정도까진아닌듯 후반갈수록 지루함'), ('8', '스포다.삼스파~빌런들 다 나온다.하지만 역대급 여주인공들은 하나도 안 나온다는거...'), ('2', '노잼임 놋북으로봐도됨'), ('8', '처음엔 기대를 많이 해서 그런가 실망했는데 곱씹을수록 잘 만든 것 같다'), ('10', '다시 돌아온 윌렘 대포의 광기어린 그린 고블린연기는 진짜 전율임..'), ('10', '주름진 토비를 보고 왠지모를 애석한 마음이 들기도 잠시, 닥터 옥토퍼스와의 한 장면만으로 그의 성장을 함께했다는 기분이 들었다. 누가 뭐래도 내겐 토비를 이길 스파이더맨은 없을 거 같다. 어느 다른 유니버스에서 mj와 함께 우리들의 이웃친구가 돼줄 스파이더맨들의 행복을 빌어본다.'), ('10', '마블 팬이면 안 볼수 없음....앤드류 가필드와 토비 맥과이어 나올때 소오오름...'), ('10', '인생 영화였습니당 !'), ('10', '힘들때 혼자인줄 알았는데 형이 둘 있었음'), ('10', '예전 스파이더맨 영화를 전부 본 사람에게는 감동이 몇배는 더 크게 느껴질 스파이더맨 덕후를 위한 수작'), ('10', '스파이더맨을 아는 빌런들은 다 왔는데 그웬도 왔으면 좋았을텐데...'), ('10', '길게 말해 뭐해, 뭐 하나 부족한게 없다. 굿'), ('4', '별로입니다. 난잡한 스토리와 등장인물. 그냥 짬뽕.'), ('6', '그냥 내인생 최고의 피터 파커는 토비 ㅋㅋㅋ토비 나올때 와우 소리가 절로 나왔음 ㅜㅜ'), ('10', '대단한 연출,연기에 감동적인 스토리까지 ㅎㄷㄷ'), ('10', '걍 도랏다 그냥 개처돌았다'), ('10', '올해 최고의 영화 스파1편부터 이어지던 스파이더맨의 독립된 세계관을 멋지게 보여줬다'), ('10', '잊어버렸던 내 추억들과의 조우'), ('6', '스파이더맨 영화가 아닌 닥터 스트레인지 영화인가 싶은 느낌이 들었다. 세게 시공간 뒤틀리면서 스트레인지의 거울세계로 가는 장면은 정말 감탄만 나왔으나 그에비해 스파이더맨의 스토리나 액션은 아쉽다.'), ('1', '스파이더맨 개발암 캐릭터 보는내내 답답재미없었음'), ('10', '두 명의 스파이더맨이 현재의 스파이더맨(톰홀랜드)가 분노에 빠져 악당을 해치지 않도록 도와준게 너무 멋있었고, 옥토퍼스도 너무 멋있게 나와서 좋았다! 다시 보고싶을정도로 명작인 영화라고 개인적으로 생각한다'), ('10', '스파이더맨 팬이라면 꼭 봐야 될 영화'), ('10', '진짜 1회차 2회차 둘다 어우 한편만에 이렇게알찬 스토리를 볼 수 있어 좋았어요..하 진짜말로 표현할 수 없네요 왜 엔드게임 급이라 하는지 알 것 같습니다 크리스마스의 선물같은 영화에요 그니까 크리스마스 때 선물받으러 다시 보러갑니다 한번 보기엔 놓치는게 너무 많아 다시 꼼꼼히..알차게 보려구요 ㅎㅎ'), ('6', '이전 시리즈에 나왔던 캐릭터들이 다시 등장한다는 것 빼곤 딱히 감상 포인트가 없고 총체적 난국이다. 톰 홀랜드는 왜 자꾸 쳐나대며 빌런들은 또 왜 이따구로 묘사했는지... 네드 센세는 계속 무시만 당하다가 마지막에 겨우 산소호흡기달아서 수명 연장하던데, 이럴 ...

# %%
import pandas as pd
df = pd.DataFrame(comment_list,columns=['rate','comment'])
df.to_csv('spider_naver_comment_blank_removed_minimum.csv', encoding='utf-8', index = False)

# %% [markdown]
# ## 2) 텍스트 전처리를 위한 데이터 셋 살펴보기

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("https://raw.githubusercontent.com/nexussord/HUFS_MLP/main/spider_naver_comment_blank_removed.csv")

# %%
df.head()
# Out:
#    rate                                            comment
# 0    10                               스파이더맨 팬이라면 꼭 봐야 될 영화
# 1    10  진짜 1회차 2회차 둘다 어우 한편만에 이렇게알찬 스토리를 볼 수 있어 좋았어요.....
# 2     6  이전 시리즈에 나왔던 캐릭터들이 다시 등장한다는 것 빼곤 딱히 감상 포인트가 없고 ...
# 3    10                                    스파이더맨 총집합  최고였음
# 4    10  거미극혐하는사람이 거미인간 좋아하게 만드는 영화임 마블영화본거중에 난 이게 1위타노...

# %%
df.shape
# Out:
# (10000, 2)

# %%
df.isnull().sum() # 데이터 무결성 확인
# Out:
# rate         0
# comment    644
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9361 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rate     9361 non-null   int64
#  1   comment  9361 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 219.4+ KB

# %%
df['comment'][20]
# Out:
# '처음 본 전율을 잊고싶지 않다.'

# %%
len(df['comment'].values.sum())
# Out:
# 370020

# %% [markdown]
# ## 3) 한국어 텍스트 전처리

# %% [markdown]
# ### Konlpy 설치

# %%
# !pip install konlpy==0.5.1 jpype1
# Out:
# Requirement already satisfied: konlpy==0.5.1 in /Users/tonykim/opt/anaconda3/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: jpype1 in /Users/tonykim/opt/anaconda3/lib/python3.8/site-packages (0.6.3)

# %% [markdown]
# ### 정규표현식 적용

# %%
import re

def filter(text):
    korean = re.compile('[^ ㄱ-ㅣ가-힣]') # 한글만 추출할 수 있게끔
    result = korean.sub('', text)
    return result

# %%
filter(df['comment'][19])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-196f84f0e58b> in <module>
# ----> 1 filter(df['comment'][19])
#
# <ipython-input-54-04ad4b3c8d47> in filter(text)
#       3 def filter(text):
#       4     korean = re.compile('[^ ㄱ-ㅣ가-힣]') # 한글만 추출할 수 있게끔
# ----> 5     result = korean.sub('', text)
#       6     return result
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# ### 명사 형태소 추출

# %%
from konlpy.tag import Okt
from collections import Counter

nouns_tagger = Okt()
nouns = nouns_tagger.nouns(filter(df['comment'][9]))
nouns
# Out:
# ['인피니티', '워', '이후', '가장', '마블', '영화']

# %%
nouns = nouns_tagger.nouns(filter("".join(df['comment'].tolist()))) # corpus(전체)에서 명사 형태소 추출
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-6924832f26e7> in <module>
# ----> 1 nouns = nouns_tagger.nouns(filter("".join(df['comment'].tolist()))) # corpus(전체)에서 명사 형태소 추출
#
# TypeError: sequence item 19: expected str instance, float found
